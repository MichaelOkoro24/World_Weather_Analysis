# %%
import pandas as pd
from citipy import citipy
import numpy as np
import pandas as pd
import requests
import json
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
# Import the API key.
from config import weather_api_key

# %%
#Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-180, high=180, size=2000)
lat_lngs =zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=508d05ccf2575a504cfabb5814a2e503

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=508d05ccf2575a504cfabb5814a2e503&q=Boston

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Starting URL for Weather Map API Call.
   
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather ["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_description
                           })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | wuzhou
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | los llanos de aridane
# Processing Record 5 of Set 1 | marion
# Processing Record 6 of Set 1 | kimbe
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | mareeba
# Processing Record 12 of Set 1 | nikolskoye
# Processing Record 13 of Set 1 | cherskiy
# Processing Record 14 of Set 1 | leningradskiy
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | pacific grove
# Processing Record 17 of Set 1 | bredasdorp
# Processing Record 18 of Set 1 | morondava
# Processing Record 19 of Set 1 | namibe
# Processing Record 20 of Set 1 | kamenka
# Processing Record 21 of Set 1 | ancud
# Processing Record 22 of Set 1 | kaitangata
# Processing Record 23 of Set 1 | eyl
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | presidencia roque saenz pena
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | narsaq
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | ilulissat
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | kodiak
# Processing Record 37 of Set 1 | leshukonskoye
# Processing Record 38 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 1 | codrington
# Processing Record 40 of Set 1 | hambantota
# Processing Record 41 of Set 1 | spirit river
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | grand-santi
# Processing Record 44 of Set 1 | vryburg
# Processing Record 45 of Set 1 | hobyo
# Processing Record 46 of Set 1 | skjervoy
# Processing Record 47 of Set 1 | belaya gora
# Processing Record 48 of Set 1 | flin flon
# Processing Record 49 of Set 1 | ambon
# Processing Record 50 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 2 | lebu
# Processing Record 2 of Set 2 | gurupa
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | ahar
# Processing Record 5 of Set 2 | condoto
# Processing Record 6 of Set 2 | arrecife
# Processing Record 7 of Set 2 | miri
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | ojinaga
# Processing Record 10 of Set 2 | puerto escondido
# Processing Record 11 of Set 2 | nanortalik
# Processing Record 12 of Set 2 | katsuura
# Processing Record 13 of Set 2 | salalah
# Processing Record 14 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 2 | shenjiamen
# Processing Record 16 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | samana
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | knyaze-volkonskoye
# Processing Record 21 of Set 2 | akyab
# Processing Record 22 of Set 2 | rolim de moura
# City not found. Skipping...
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | vaxjo
# Processing Record 25 of Set 2 | tiznit
# Processing Record 26 of Set 2 | tacuarembo
# Processing Record 27 of Set 2 | banmo
# City not found. Skipping...
# Processing Record 28 of Set 2 | tombouctou
# Processing Record 29 of Set 2 | mandan
# Processing Record 30 of Set 2 | salinopolis
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | albany
# Processing Record 33 of Set 2 | acapulco
# Processing Record 34 of Set 2 | nakhon thai
# Processing Record 35 of Set 2 | bogorodskoye
# Processing Record 36 of Set 2 | atuona
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | castro
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | regina
# Processing Record 41 of Set 2 | komsomolskiy
# Processing Record 42 of Set 2 | north bend
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | bony
# Processing Record 45 of Set 2 | quatre cocos
# Processing Record 46 of Set 2 | meulaboh
# Processing Record 47 of Set 2 | sabang
# Processing Record 48 of Set 2 | bluff
# Processing Record 49 of Set 2 | vila do maio
# Processing Record 50 of Set 2 | vaini
# Processing Record 1 of Set 3 | provideniya
# Processing Record 2 of Set 3 | cidreira
# Processing Record 3 of Set 3 | buala
# Processing Record 4 of Set 3 | guerrero negro
# Processing Record 5 of Set 3 | ixtapa
# Processing Record 6 of Set 3 | chuy
# Processing Record 7 of Set 3 | santo antonio do ica
# Processing Record 8 of Set 3 | mossendjo
# Processing Record 9 of Set 3 | lompoc
# Processing Record 10 of Set 3 | hilo
# Processing Record 11 of Set 3 | mahajanga
# Processing Record 12 of Set 3 | selikhino
# Processing Record 13 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 3 | batagay
# Processing Record 15 of Set 3 | saint-georges
# Processing Record 16 of Set 3 | imbituba
# Processing Record 17 of Set 3 | kardailovo
# Processing Record 18 of Set 3 | lagoa
# Processing Record 19 of Set 3 | kupang
# Processing Record 20 of Set 3 | solovetskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | iquitos
# Processing Record 22 of Set 3 | namatanai
# Processing Record 23 of Set 3 | port alfred
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | takoradi
# Processing Record 26 of Set 3 | eureka
# Processing Record 27 of Set 3 | the valley
# Processing Record 28 of Set 3 | la paz
# Processing Record 29 of Set 3 | tobermory
# Processing Record 30 of Set 3 | cedar city
# Processing Record 31 of Set 3 | baker city
# Processing Record 32 of Set 3 | praia
# Processing Record 33 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 3 | huarmey
# Processing Record 35 of Set 3 | kutum
# Processing Record 36 of Set 3 | cockburn town
# Processing Record 37 of Set 3 | bandarbeyla
# Processing Record 38 of Set 3 | prince rupert
# Processing Record 39 of Set 3 | mrirt
# City not found. Skipping...
# Processing Record 40 of Set 3 | hermanus
# Processing Record 41 of Set 3 | kruisfontein
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | tiarei
# Processing Record 44 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 45 of Set 3 | beidao
# Processing Record 46 of Set 3 | biltine
# Processing Record 47 of Set 3 | abong mbang
# Processing Record 48 of Set 3 | bonavista
# Processing Record 49 of Set 3 | bengkulu
# Processing Record 50 of Set 3 | iranshahr
# Processing Record 1 of Set 4 | la rioja
# Processing Record 2 of Set 4 | chokurdakh
# Processing Record 3 of Set 4 | amuntai
# Processing Record 4 of Set 4 | altay
# Processing Record 5 of Set 4 | tres arroyos
# Processing Record 6 of Set 4 | yumen
# Processing Record 7 of Set 4 | santo angelo
# Processing Record 8 of Set 4 | aklavik
# Processing Record 9 of Set 4 | pitimbu
# Processing Record 10 of Set 4 | tutin
# Processing Record 11 of Set 4 | mackay
# Processing Record 12 of Set 4 | potsdam
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | ponta do sol
# Processing Record 15 of Set 4 | saint-philippe
# Processing Record 16 of Set 4 | mehamn
# Processing Record 17 of Set 4 | treia
# Processing Record 18 of Set 4 | puerto quijarro
# Processing Record 19 of Set 4 | morehead
# Processing Record 20 of Set 4 | cairns
# Processing Record 21 of Set 4 | margherita
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | brigantine
# Processing Record 25 of Set 4 | port hedland
# Processing Record 26 of Set 4 | ribas do rio pardo
# Processing Record 27 of Set 4 | ostrovnoy
# Processing Record 28 of Set 4 | sanary-sur-mer
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | hailar
# Processing Record 31 of Set 4 | bastia
# Processing Record 32 of Set 4 | riyadh
# Processing Record 33 of Set 4 | zyryanka
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | luderitz
# Processing Record 37 of Set 4 | talnakh
# Processing Record 38 of Set 4 | chegdomyn
# Processing Record 39 of Set 4 | mamakan
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | hithadhoo
# Processing Record 42 of Set 4 | pochutla
# Processing Record 43 of Set 4 | mayo
# Processing Record 44 of Set 4 | san mateo ixtatan
# Processing Record 45 of Set 4 | fortuna
# Processing Record 46 of Set 4 | mitchell
# Processing Record 47 of Set 4 | matara
# Processing Record 48 of Set 4 | marawi
# Processing Record 49 of Set 4 | qaqortoq
# Processing Record 50 of Set 4 | ueno
# Processing Record 1 of Set 5 | mount gambier
# Processing Record 2 of Set 5 | labuan
# Processing Record 3 of Set 5 | lucea
# Processing Record 4 of Set 5 | souillac
# Processing Record 5 of Set 5 | tilichiki
# Processing Record 6 of Set 5 | porto novo
# Processing Record 7 of Set 5 | bambous virieux
# Processing Record 8 of Set 5 | surbo
# Processing Record 9 of Set 5 | bethel
# Processing Record 10 of Set 5 | huilong
# Processing Record 11 of Set 5 | maniitsoq
# Processing Record 12 of Set 5 | torbay
# Processing Record 13 of Set 5 | camacha
# Processing Record 14 of Set 5 | elizabeth city
# Processing Record 15 of Set 5 | myitkyina
# Processing Record 16 of Set 5 | mildura
# Processing Record 17 of Set 5 | itoman
# Processing Record 18 of Set 5 | padang
# Processing Record 19 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 5 | antropovo
# Processing Record 21 of Set 5 | bonfim
# Processing Record 22 of Set 5 | tecoanapa
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | guayaramerin
# Processing Record 25 of Set 5 | pisco
# Processing Record 26 of Set 5 | shingu
# Processing Record 27 of Set 5 | jibuti
# Processing Record 28 of Set 5 | makokou
# Processing Record 29 of Set 5 | dikson
# Processing Record 30 of Set 5 | ust-tarka
# Processing Record 31 of Set 5 | taoudenni
# Processing Record 32 of Set 5 | shellbrook
# Processing Record 33 of Set 5 | monrovia
# Processing Record 34 of Set 5 | yarmouth
# Processing Record 35 of Set 5 | byadgi
# Processing Record 36 of Set 5 | port blair
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 5 | mata
# Processing Record 40 of Set 5 | juneau
# Processing Record 41 of Set 5 | khani
# Processing Record 42 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 5 | mindelo
# Processing Record 44 of Set 5 | sorland
# Processing Record 45 of Set 5 | uzventis
# Processing Record 46 of Set 5 | kavieng
# Processing Record 47 of Set 5 | lasa
# Processing Record 48 of Set 5 | conceicao do araguaia
# Processing Record 49 of Set 5 | carnarvon
# Processing Record 50 of Set 5 | east london
# Processing Record 1 of Set 6 | grand gaube
# Processing Record 2 of Set 6 | coruripe
# Processing Record 3 of Set 6 | laredo
# Processing Record 4 of Set 6 | sal rei
# Processing Record 5 of Set 6 | hyeres
# Processing Record 6 of Set 6 | hlotse
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | mahibadhoo
# Processing Record 9 of Set 6 | bang saphan
# Processing Record 10 of Set 6 | victoria
# Processing Record 11 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 12 of Set 6 | duz
# City not found. Skipping...
# Processing Record 13 of Set 6 | zhuanghe
# Processing Record 14 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 6 | burnie
# Processing Record 16 of Set 6 | chimay
# Processing Record 17 of Set 6 | alta floresta
# Processing Record 18 of Set 6 | samarai
# Processing Record 19 of Set 6 | benjamin constant
# Processing Record 20 of Set 6 | panaba
# Processing Record 21 of Set 6 | ballarat
# Processing Record 22 of Set 6 | sitka
# Processing Record 23 of Set 6 | cabayaoasan
# Processing Record 24 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 6 | pangai
# Processing Record 26 of Set 6 | qaanaaq
# Processing Record 27 of Set 6 | tautira
# Processing Record 28 of Set 6 | grand baie
# Processing Record 29 of Set 6 | rehoboth
# Processing Record 30 of Set 6 | upernavik
# Processing Record 31 of Set 6 | coihaique
# Processing Record 32 of Set 6 | tuatapere
# Processing Record 33 of Set 6 | somerset west
# Processing Record 34 of Set 6 | miguelopolis
# Processing Record 35 of Set 6 | ratangarh
# Processing Record 36 of Set 6 | paka
# Processing Record 37 of Set 6 | vigrestad
# Processing Record 38 of Set 6 | naantali
# Processing Record 39 of Set 6 | santa rosa
# Processing Record 40 of Set 6 | te anau
# Processing Record 41 of Set 6 | plettenberg bay
# Processing Record 42 of Set 6 | mbandaka
# Processing Record 43 of Set 6 | manta
# Processing Record 44 of Set 6 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 6 | galle
# Processing Record 46 of Set 6 | villa bruzual
# Processing Record 47 of Set 6 | erenhot
# Processing Record 48 of Set 6 | san bartolome de tirajana
# Processing Record 49 of Set 6 | cayenne
# Processing Record 50 of Set 6 | grindavik
# Processing Record 1 of Set 7 | san quintin
# Processing Record 2 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 3 of Set 7 | pahrump
# Processing Record 4 of Set 7 | sivaki
# Processing Record 5 of Set 7 | saint george
# Processing Record 6 of Set 7 | winnemucca
# Processing Record 7 of Set 7 | veracruz
# Processing Record 8 of Set 7 | todos santos
# Processing Record 9 of Set 7 | maragogi
# Processing Record 10 of Set 7 | hofn
# Processing Record 11 of Set 7 | dalvik
# Processing Record 12 of Set 7 | dingle
# Processing Record 13 of Set 7 | nederland
# Processing Record 14 of Set 7 | vila velha
# Processing Record 15 of Set 7 | vangaindrano
# Processing Record 16 of Set 7 | asau
# Processing Record 17 of Set 7 | yar-sale
# Processing Record 18 of Set 7 | derbent
# Processing Record 19 of Set 7 | dzhusaly
# City not found. Skipping...
# Processing Record 20 of Set 7 | uglekamensk
# Processing Record 21 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 22 of Set 7 | atar
# Processing Record 23 of Set 7 | monroe
# Processing Record 24 of Set 7 | ulaangom
# Processing Record 25 of Set 7 | axim
# Processing Record 26 of Set 7 | qasigiannguit
# Processing Record 27 of Set 7 | ayan
# Processing Record 28 of Set 7 | burdur
# Processing Record 29 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 7 | kristianstad
# Processing Record 31 of Set 7 | soc trang
# Processing Record 32 of Set 7 | pouebo
# Processing Record 33 of Set 7 | luangwa
# Processing Record 34 of Set 7 | hit
# Processing Record 35 of Set 7 | aljezur
# Processing Record 36 of Set 7 | kinsale
# Processing Record 37 of Set 7 | moose factory
# Processing Record 38 of Set 7 | flinders
# Processing Record 39 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 7 | haines junction
# Processing Record 41 of Set 7 | nhulunbuy
# Processing Record 42 of Set 7 | baruun-urt
# Processing Record 43 of Set 7 | herrin
# Processing Record 44 of Set 7 | avera
# Processing Record 45 of Set 7 | kununurra
# Processing Record 46 of Set 7 | kodinsk
# Processing Record 47 of Set 7 | coahuayana
# Processing Record 48 of Set 7 | longyearbyen
# Processing Record 49 of Set 7 | saint-leu
# Processing Record 50 of Set 7 | doume
# Processing Record 1 of Set 8 | ossora
# Processing Record 2 of Set 8 | kyaikto
# Processing Record 3 of Set 8 | berezovka
# Processing Record 4 of Set 8 | vao
# Processing Record 5 of Set 8 | nyurba
# Processing Record 6 of Set 8 | qingyuan
# Processing Record 7 of Set 8 | amga
# Processing Record 8 of Set 8 | goderich
# Processing Record 9 of Set 8 | bilma
# Processing Record 10 of Set 8 | comodoro rivadavia
# Processing Record 11 of Set 8 | tahta
# Processing Record 12 of Set 8 | russell
# Processing Record 13 of Set 8 | tibu
# Processing Record 14 of Set 8 | scarborough
# Processing Record 15 of Set 8 | goryachegorsk
# Processing Record 16 of Set 8 | coquimbo
# Processing Record 17 of Set 8 | kushima
# Processing Record 18 of Set 8 | fairbanks
# Processing Record 19 of Set 8 | puerto colombia
# Processing Record 20 of Set 8 | carmen
# Processing Record 21 of Set 8 | kavaratti
# Processing Record 22 of Set 8 | barcelos
# Processing Record 23 of Set 8 | norman wells
# Processing Record 24 of Set 8 | windhoek
# Processing Record 25 of Set 8 | kargasok
# Processing Record 26 of Set 8 | tessalit
# Processing Record 27 of Set 8 | bage
# Processing Record 28 of Set 8 | kolosovka
# Processing Record 29 of Set 8 | linshu
# City not found. Skipping...
# Processing Record 30 of Set 8 | hualmay
# Processing Record 31 of Set 8 | oranjemund
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | santa isabel do rio negro
# Processing Record 34 of Set 8 | joshimath
# Processing Record 35 of Set 8 | homer
# Processing Record 36 of Set 8 | bom jesus da lapa
# Processing Record 37 of Set 8 | vanimo
# Processing Record 38 of Set 8 | moron
# Processing Record 39 of Set 8 | abakaliki
# Processing Record 40 of Set 8 | hazorasp
# Processing Record 41 of Set 8 | buraydah
# Processing Record 42 of Set 8 | dubbo
# Processing Record 43 of Set 8 | nantucket
# Processing Record 44 of Set 8 | bathsheba
# Processing Record 45 of Set 8 | dunedin
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | peleduy
# Processing Record 48 of Set 8 | sicuani
# Processing Record 49 of Set 8 | verkhnevilyuysk
# Processing Record 50 of Set 8 | shchuchye
# City not found. Skipping...
# Processing Record 1 of Set 9 | punta de piedra
# Processing Record 2 of Set 9 | linxia
# Processing Record 3 of Set 9 | abadan
# Processing Record 4 of Set 9 | vila franca do campo
# Processing Record 5 of Set 9 | waipawa
# Processing Record 6 of Set 9 | svetlogorsk
# Processing Record 7 of Set 9 | comacchio
# Processing Record 8 of Set 9 | harnosand
# Processing Record 9 of Set 9 | paamiut
# Processing Record 10 of Set 9 | amahai
# Processing Record 11 of Set 9 | killybegs
# Processing Record 12 of Set 9 | port hardy
# Processing Record 13 of Set 9 | abu samrah
# Processing Record 14 of Set 9 | wanaka
# Processing Record 15 of Set 9 | kahului
# Processing Record 16 of Set 9 | batagay-alyta
# Processing Record 17 of Set 9 | kuhestan
# City not found. Skipping...
# Processing Record 18 of Set 9 | krasnyy kut
# Processing Record 19 of Set 9 | uyemskiy
# Processing Record 20 of Set 9 | berlevag
# Processing Record 21 of Set 9 | santiago del estero
# Processing Record 22 of Set 9 | walvis bay
# Processing Record 23 of Set 9 | vestmanna
# Processing Record 24 of Set 9 | jaumave
# Processing Record 25 of Set 9 | poso
# Processing Record 26 of Set 9 | gigmoto
# Processing Record 27 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 28 of Set 9 | basqal
# Processing Record 29 of Set 9 | yulara
# Processing Record 30 of Set 9 | vieques
# Processing Record 31 of Set 9 | hibbing
# Processing Record 32 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 9 | nizhniy baskunchak
# Processing Record 34 of Set 9 | laguna
# Processing Record 35 of Set 9 | turtas
# Processing Record 36 of Set 9 | wukari
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | north platte
# Processing Record 39 of Set 9 | nabire
# Processing Record 40 of Set 9 | suez
# Processing Record 41 of Set 9 | mopti
# Processing Record 42 of Set 9 | san roque
# Processing Record 43 of Set 9 | chongwe
# Processing Record 44 of Set 9 | hami
# Processing Record 45 of Set 9 | jiblah
# Processing Record 46 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 47 of Set 9 | aykhal
# Processing Record 48 of Set 9 | rio pardo de minas
# Processing Record 49 of Set 9 | ucluelet
# Processing Record 50 of Set 9 | pevek
# Processing Record 1 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 2 of Set 10 | iqaluit
# Processing Record 3 of Set 10 | faanui
# Processing Record 4 of Set 10 | mago
# Processing Record 5 of Set 10 | katangli
# Processing Record 6 of Set 10 | fare
# Processing Record 7 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 10 | broome
# Processing Record 9 of Set 10 | shubarshi
# Processing Record 10 of Set 10 | bolshoy lug
# Processing Record 11 of Set 10 | lubango
# Processing Record 12 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 13 of Set 10 | mosjoen
# Processing Record 14 of Set 10 | skiros
# City not found. Skipping...
# Processing Record 15 of Set 10 | banda aceh
# Processing Record 16 of Set 10 | dukat
# Processing Record 17 of Set 10 | madaoua
# Processing Record 18 of Set 10 | geraldton
# Processing Record 19 of Set 10 | warmbad
# Processing Record 20 of Set 10 | idaho falls
# Processing Record 21 of Set 10 | mergui
# City not found. Skipping...
# Processing Record 22 of Set 10 | masuguru
# Processing Record 23 of Set 10 | wamba
# Processing Record 24 of Set 10 | buqayq
# City not found. Skipping...
# Processing Record 25 of Set 10 | pemba
# Processing Record 26 of Set 10 | port moresby
# Processing Record 27 of Set 10 | nadym
# Processing Record 28 of Set 10 | stykkisholmur
# Processing Record 29 of Set 10 | kefamenanu
# Processing Record 30 of Set 10 | huazolotitlan
# City not found. Skipping...
# Processing Record 31 of Set 10 | hervey bay
# Processing Record 32 of Set 10 | wetaskiwin
# Processing Record 33 of Set 10 | olavarria
# Processing Record 34 of Set 10 | ponta delgada
# Processing Record 35 of Set 10 | novikovo
# Processing Record 36 of Set 10 | khuzhir
# Processing Record 37 of Set 10 | nuevo laredo
# Processing Record 38 of Set 10 | ganzhou
# Processing Record 39 of Set 10 | naze
# Processing Record 40 of Set 10 | emerald
# Processing Record 41 of Set 10 | marystown
# Processing Record 42 of Set 10 | portland
# Processing Record 43 of Set 10 | slave lake
# Processing Record 44 of Set 10 | escanaba
# Processing Record 45 of Set 10 | noumea
# Processing Record 46 of Set 10 | cradock
# Processing Record 47 of Set 10 | saint-joseph
# Processing Record 48 of Set 10 | cascais
# Processing Record 49 of Set 10 | portree
# Processing Record 50 of Set 10 | muskegon
# Processing Record 1 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 11 | kirakira
# Processing Record 3 of Set 11 | sao filipe
# Processing Record 4 of Set 11 | caxito
# Processing Record 5 of Set 11 | tari
# Processing Record 6 of Set 11 | garmsar
# Processing Record 7 of Set 11 | vila
# Processing Record 8 of Set 11 | phetchabun
# Processing Record 9 of Set 11 | olden
# Processing Record 10 of Set 11 | alofi
# Processing Record 11 of Set 11 | yerbogachen
# Processing Record 12 of Set 11 | boyolangu
# Processing Record 13 of Set 11 | cabo san lucas
# Processing Record 14 of Set 11 | repatriacion
# Processing Record 15 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 11 | uvat
# Processing Record 17 of Set 11 | ler
# Processing Record 18 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 11 | bocana de paiwas
# Processing Record 20 of Set 11 | szihalom
# Processing Record 21 of Set 11 | labuhan
# Processing Record 22 of Set 11 | itaituba
# Processing Record 23 of Set 11 | sartell
# Processing Record 24 of Set 11 | talcahuano
# Processing Record 25 of Set 11 | mandalgovi
# Processing Record 26 of Set 11 | pasco
# Processing Record 27 of Set 11 | adelaide
# Processing Record 28 of Set 11 | sala
# Processing Record 29 of Set 11 | poum
# Processing Record 30 of Set 11 | airai
# Processing Record 31 of Set 11 | saint-augustin
# Processing Record 32 of Set 11 | mount pleasant
# Processing Record 33 of Set 11 | hohhot
# Processing Record 34 of Set 11 | san vicente
# Processing Record 35 of Set 11 | gazojak
# Processing Record 36 of Set 11 | khovu-aksy
# Processing Record 37 of Set 11 | san cristobal
# Processing Record 38 of Set 11 | payson
# Processing Record 39 of Set 11 | douglas
# Processing Record 40 of Set 11 | mamlyutka
# Processing Record 41 of Set 11 | chulym
# Processing Record 42 of Set 11 | aksu
# Processing Record 43 of Set 11 | cartagena
# Processing Record 44 of Set 11 | hovd
# Processing Record 45 of Set 11 | persianovskiy
# Processing Record 46 of Set 11 | kommunar
# Processing Record 47 of Set 11 | soyo
# Processing Record 48 of Set 11 | evensk
# Processing Record 49 of Set 11 | yashkul
# Processing Record 50 of Set 11 | hauterive
# Processing Record 1 of Set 12 | manchester
# Processing Record 2 of Set 12 | rock springs
# Processing Record 3 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 4 of Set 12 | izumo
# Processing Record 5 of Set 12 | creel
# Processing Record 6 of Set 12 | lorengau
# Processing Record 7 of Set 12 | zaltan
# Processing Record 8 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 12 | invermere
# Processing Record 10 of Set 12 | grants
# Processing Record 11 of Set 12 | lesnoye
# Processing Record 12 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 13 of Set 12 | linhares
# Processing Record 14 of Set 12 | kathmandu
# Processing Record 15 of Set 12 | tupaciguara
# Processing Record 16 of Set 12 | port augusta
# Processing Record 17 of Set 12 | viedma
# Processing Record 18 of Set 12 | necochea
# Processing Record 19 of Set 12 | kalmunai
# Processing Record 20 of Set 12 | samdrup jongkhar
# Processing Record 21 of Set 12 | muros
# Processing Record 22 of Set 12 | la roda
# Processing Record 23 of Set 12 | marsh harbour
# Processing Record 24 of Set 12 | ola
# Processing Record 25 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 12 | constitucion
# Processing Record 27 of Set 12 | babu
# Processing Record 28 of Set 12 | havre-saint-pierre
# Processing Record 29 of Set 12 | ouadda
# Processing Record 30 of Set 12 | novobiryusinskiy
# Processing Record 31 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 12 | palkaka
# City not found. Skipping...
# Processing Record 33 of Set 12 | rocha
# Processing Record 34 of Set 12 | sibolga
# Processing Record 35 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 36 of Set 12 | aguimes
# Processing Record 37 of Set 12 | rio verde de mato grosso
# Processing Record 38 of Set 12 | bayanday
# Processing Record 39 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 12 | alexandria
# Processing Record 41 of Set 12 | nouadhibou
# Processing Record 42 of Set 12 | lyubech
# Processing Record 43 of Set 12 | nuuk
# Processing Record 44 of Set 12 | sens
# Processing Record 45 of Set 12 | kattivakkam
# Processing Record 46 of Set 12 | salas
# Processing Record 47 of Set 12 | hay river
# Processing Record 48 of Set 12 | wolgast
# Processing Record 49 of Set 12 | dmitriyevka
# Processing Record 50 of Set 12 | seminole
# Processing Record 1 of Set 13 | partsa
# Processing Record 2 of Set 13 | hasaki
# Processing Record 3 of Set 13 | ketchikan
# Processing Record 4 of Set 13 | vondrozo
# Processing Record 5 of Set 13 | bayji
# Processing Record 6 of Set 13 | usinsk
# Processing Record 7 of Set 13 | guabito
# Processing Record 8 of Set 13 | garoua
# Processing Record 9 of Set 13 | mandla
# Processing Record 10 of Set 13 | zeya
# Processing Record 11 of Set 13 | tsuruoka
# Processing Record 12 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 13 | tazovskiy
# Processing Record 14 of Set 13 | faya
# Processing Record 15 of Set 13 | monywa
# Processing Record 16 of Set 13 | linchuan
# City not found. Skipping...
# Processing Record 17 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 18 of Set 13 | belmonte
# Processing Record 19 of Set 13 | vardo
# Processing Record 20 of Set 13 | saint-pierre
# Processing Record 21 of Set 13 | ndele
# Processing Record 22 of Set 13 | huangpi
# Processing Record 23 of Set 13 | klyuchi
# Processing Record 24 of Set 13 | luanda
# Processing Record 25 of Set 13 | bokovskaya
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | shimoda
# Processing Record 28 of Set 13 | varhaug
# Processing Record 29 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 30 of Set 13 | bilibino
# Processing Record 31 of Set 13 | huntsville
# Processing Record 32 of Set 13 | canatlan
# Processing Record 33 of Set 13 | lively
# Processing Record 34 of Set 13 | bati
# Processing Record 35 of Set 13 | totma
# Processing Record 36 of Set 13 | carauari
# Processing Record 37 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 39 of Set 13 | kochubey
# Processing Record 40 of Set 13 | quartucciu
# Processing Record 41 of Set 13 | kihei
# Processing Record 42 of Set 13 | mwinilunga
# Processing Record 43 of Set 13 | tenamaxtlan
# Processing Record 44 of Set 13 | beryslav
# Processing Record 45 of Set 13 | maningrida
# Processing Record 46 of Set 13 | kolbermoor
# Processing Record 47 of Set 13 | whitehorse
# Processing Record 48 of Set 13 | vuktyl
# Processing Record 49 of Set 13 | bridlington
# Processing Record 50 of Set 13 | kieta
# Processing Record 1 of Set 14 | turan
# Processing Record 2 of Set 14 | saryg-sep
# Processing Record 3 of Set 14 | sao joaquim
# Processing Record 4 of Set 14 | ipixuna
# Processing Record 5 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 6 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 7 of Set 14 | smidovich
# Processing Record 8 of Set 14 | san blas
# Processing Record 9 of Set 14 | tevaitoa
# Processing Record 10 of Set 14 | sao jose da coroa grande
# Processing Record 11 of Set 14 | damghan
# Processing Record 12 of Set 14 | mount isa
# Processing Record 13 of Set 14 | shubarkuduk
# Processing Record 14 of Set 14 | beringovskiy
# Processing Record 15 of Set 14 | rawson
# Processing Record 16 of Set 14 | sao sebastiao
# Processing Record 17 of Set 14 | kuusamo
# Processing Record 18 of Set 14 | okato
# Processing Record 19 of Set 14 | boa vista
# Processing Record 20 of Set 14 | katha
# City not found. Skipping...
# Processing Record 21 of Set 14 | chapais
# Processing Record 22 of Set 14 | jacareacanga
# Processing Record 23 of Set 14 | rock sound
# Processing Record 24 of Set 14 | gari
# Processing Record 25 of Set 14 | hammerfest
# Processing Record 26 of Set 14 | gannan
# Processing Record 27 of Set 14 | bangkalan
# Processing Record 28 of Set 14 | aripuana
# Processing Record 29 of Set 14 | belyy yar
# Processing Record 30 of Set 14 | wajima
# Processing Record 31 of Set 14 | sept-iles
# Processing Record 32 of Set 14 | tornio
# Processing Record 33 of Set 14 | payo
# Processing Record 34 of Set 14 | koppa
# Processing Record 35 of Set 14 | guilin
# Processing Record 36 of Set 14 | solnechnyy
# Processing Record 37 of Set 14 | choma
# Processing Record 38 of Set 14 | itarema
# Processing Record 39 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 14 | panshi
# Processing Record 41 of Set 14 | tura
# Processing Record 42 of Set 14 | pangkalanbuun
# Processing Record 43 of Set 14 | barcelona
# Processing Record 44 of Set 14 | plastun
# Processing Record 45 of Set 14 | mana
# Processing Record 46 of Set 14 | mul
# Processing Record 47 of Set 14 | praya
# Processing Record 48 of Set 14 | unity
# Processing Record 49 of Set 14 | yalta
# Processing Record 50 of Set 14 | korla
# Processing Record 1 of Set 15 | richards bay
# Processing Record 2 of Set 15 | tottori
# City not found. Skipping...
# Processing Record 3 of Set 15 | ewa beach
# Processing Record 4 of Set 15 | zhigansk
# Processing Record 5 of Set 15 | newport
# Processing Record 6 of Set 15 | kolokani
# Processing Record 7 of Set 15 | hyvinkaa
# Processing Record 8 of Set 15 | touros
# Processing Record 9 of Set 15 | tigil
# Processing Record 10 of Set 15 | merauke
# Processing Record 11 of Set 15 | susanville
# Processing Record 12 of Set 15 | caravelas
# Processing Record 13 of Set 15 | morgan city
# Processing Record 14 of Set 15 | buchanan
# Processing Record 15 of Set 15 | jensen beach
# Processing Record 16 of Set 15 | arvika
# Processing Record 17 of Set 15 | westport
# Processing Record 18 of Set 15 | kiruna
# Processing Record 19 of Set 15 | hallein
# Processing Record 20 of Set 15 | klaksvik
# Processing Record 21 of Set 15 | kaeo
# Processing Record 22 of Set 15 | singanallur
# Processing Record 23 of Set 15 | roma
# Processing Record 24 of Set 15 | lavrentiya
# Processing Record 25 of Set 15 | spassk
# Processing Record 26 of Set 15 | broken hill
# Processing Record 27 of Set 15 | huangnihe
# Processing Record 28 of Set 15 | svetlyy
# Processing Record 29 of Set 15 | neya
# Processing Record 30 of Set 15 | coxim
# Processing Record 31 of Set 15 | ahipara
# Processing Record 32 of Set 15 | birjand
# Processing Record 33 of Set 15 | uk
# City not found. Skipping...
# Processing Record 34 of Set 15 | ormara
# Processing Record 35 of Set 15 | salou
# Processing Record 36 of Set 15 | san jose
# Processing Record 37 of Set 15 | mporokoso
# Processing Record 38 of Set 15 | marienburg
# Processing Record 39 of Set 15 | turinsk
# Processing Record 40 of Set 15 | farragut
# Processing Record 41 of Set 15 | ambunti
# Processing Record 42 of Set 15 | aswan
# Processing Record 43 of Set 15 | copiapo
# Processing Record 44 of Set 15 | culpeper
# Processing Record 45 of Set 15 | svendborg
# Processing Record 46 of Set 15 | lagunas
# Processing Record 47 of Set 15 | kubachi
# Processing Record 48 of Set 15 | ayakudi
# Processing Record 49 of Set 15 | pathein
# Processing Record 50 of Set 15 | santiago de cao
# Processing Record 1 of Set 16 | hirara
# Processing Record 2 of Set 16 | bongandanga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
print(city_data_df.head(10))
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0                 Wuzhou  23.4833  111.3167     79.11        93         100
# 1                   Nome  64.5011 -165.4064     52.16        59           0
# 2  Los Llanos De Aridane  28.6585  -17.9182     73.13        81           0
# 3                 Marion  39.7684  -86.1555     75.70        90         100
# 4                  Kimbe  -5.5502  150.1429     74.84        93          96
# 5              Cape Town -33.9258   18.4232     60.28        87          75
# 6              Busselton -33.6500  115.3333     53.15        93         100
# 7                Mataura -46.1927  168.8643     51.48        88          86
# 8              Mahebourg -20.4081   57.7000     70.09        64          40
# 9                Mareeba -17.0000  145.4333     63.32        90          25
#
#    Wind Speed Country                 Date Current Description
# 0        0.69      CN  2022-07-17 17:43:49     overcast clouds
# 1        5.75      US  2022-07-17 17:43:50           clear sky
# 2       16.11      ES  2022-07-17 17:43:50           clear sky
# 3       17.27      US  2022-07-17 17:43:51       moderate rain
# 4        3.96      PG  2022-07-17 17:43:51     overcast clouds
# 5       14.97      ZA  2022-07-17 17:40:27       broken clouds
# 6       13.13      AU  2022-07-17 17:43:51     overcast clouds
# 7        5.84      NZ  2022-07-17 17:43:52     overcast clouds
# 8       19.57      MU  2022-07-17 17:43:52    scattered clouds
# 9        1.99      AU  2022-07-17 17:43:52    scattered clouds

# %%
# Reorder the Columns of the DataFrame
new_column_order = ["City", "Cloudiness","Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed","Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                     City  Cloudiness Country                 Date  Humidity  \
# 0                 Wuzhou         100      CN  2022-07-17 17:43:49        93
# 1                   Nome           0      US  2022-07-17 17:43:50        59
# 2  Los Llanos De Aridane           0      ES  2022-07-17 17:43:50        81
# 3                 Marion         100      US  2022-07-17 17:43:51        90
# 4                  Kimbe          96      PG  2022-07-17 17:43:51        93
# 5              Cape Town          75      ZA  2022-07-17 17:40:27        87
# 6              Busselton         100      AU  2022-07-17 17:43:51        93
# 7                Mataura          86      NZ  2022-07-17 17:43:52        88
# 8              Mahebourg          40      MU  2022-07-17 17:43:52        64
# 9                Mareeba          25      AU  2022-07-17 17:43:52        90
#
#        Lat       Lng  Max Temp  Wind Speed Current Description
# 0  23.4833  111.3167     79.11        0.69     overcast clouds
# 1  64.5011 -165.4064     52.16        5.75           clear sky
# 2  28.6585  -17.9182     73.13       16.11           clear sky
# 3  39.7684  -86.1555     75.70       17.27       moderate rain
# 4  -5.5502  150.1429     74.84        3.96     overcast clouds
# 5 -33.9258   18.4232     60.28       14.97       broken clouds
# 6 -33.6500  115.3333     53.15       13.13     overcast clouds
# 7 -46.1927  168.8643     51.48        5.84     overcast clouds
# 8 -20.4081   57.7000     70.09       19.57    scattered clouds
# 9 -17.0000  145.4333     63.32        1.99    scattered clouds

# %%
city_data_df.to_csv('WeatherPy_Database.csv')

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
